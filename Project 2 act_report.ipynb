# %% [markdown]
# ## Report: act_report
# * Create a **250-word-minimum written report** called "act_report.pdf" or "act_report.html" that communicates the insights and displays the visualization(s) produced from your wrangled data. This is to be framed as an external document, like a blog post or magazine article, for example.

# %% [markdown]
# In this project, three dataframes were utilized for generating insights and visualization.
#
# After cleaning the quality and tidiness issues of the dataframes, including merging the three dataframes into one, I stored it as a CSV file called `twtitter_archive_maser.csv`. Then, I used an external spreadsheet software (Microsoft Excel) to further examine the dataframe.
#
# After that was done, I loaded the dataframe back into the Jupyter notebook as a dataframe called `df`. I then began analyzing the data to generate insights.
# 1. I calculated the described the data to calculate basic summary statistics.
#
# 2. I checked for the dog that has the highest retweet count.
#
# 3. I checked for the dog that has the highest favorite count.
#
# 4. I checked for the value counts of the names of the dogs.
#
# Note: None and a will be ignored here because they are invalid dog names

# %% [markdown]
# From this brief analysis, the following insights were obtained:
#
# 1. The dog with the highest retweets is a __Labrador retriever__ in the __doggo__ stage with __79515__ retweets.
#
# 2. The dog with the highest favorites is in the __puppo__ stage and has __132810__ favorites.
#
# 3. The most common dog name in the dataframe is __Charlie__.

# %% [markdown]
# In order to visualize the data, I had to import the necessary packages:

# %% [markdown]
# Now, we can make plots.
#
# The visualization in this project was a scatter plot to determine the correlation between the number of retweets and the number of favorites.
# The code for that is given below:

# %% [markdown]
# ![download.png](attachment:download.png)

# %% [markdown]
# As we can see, there is a strong positve correlation between retweet count and favorite count.
#
# This concludes the project.
